# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
veri = pd.read_excel("C:/Users/user/OneDrive/Masaüstü/SQL ÇALIŞMA/futboldata.xlsx")

# %%
veri
# Out:
#                Ad  Yas      Mevki   Oynadigi_Takim Oynadigi_Lig  \
# 0      Martinelli   21      Kanat          Arsenal    İngiltere
# 1            Saka   21      Kanat          Arsenal    İngiltere
# 2        Odegaard   24  Orta Saha          Arsenal    İngiltere
# 3         Haaland   22     Forvet         Man.City    İngiltere
# 4           Foden   22      Kanat         Man.City    İngiltere
# 5          Mahrez   32      Kanat         Man.City    İngiltere
# 6        Rashford   25      Kanat          Man.Utd    İngiltere
# 7     B.Fernandes   28  Orta Saha          Man.Utd    İngiltere
# 8          Sancho   22      Kanat          Man.Utd    İngiltere
# 9     Lewandowski   34     Forvet        Barcelona      İspanya
# 10          Pedri   20  Orta Saha        Barcelona      İspanya
# 11       Raphinha   26      Kanat        Barcelona      İspanya
# 12        Benzema   35     Forvet      Real Madrid      İspanya
# 13   Vinicius Jr.   22      Kanat      Real Madrid      İspanya
# ...

# %%
veri.describe()
# Out:
#              Yas  Oynadigi_Mac_Sayisi  Gol_Sayisi  Asist_Sayisi  Aldığı_süre  \
# count  45.000000            45.000000   45.000000     45.000000    45.000000
# mean   26.577778            32.111111   12.288889      5.488889  2257.288889
# std     4.788665             5.223297    6.824495      3.781668   662.411696
# min    18.000000            19.000000    5.000000      0.000000   625.000000
# 25%    23.000000            30.000000    7.000000      3.000000  1897.000000
# 50%    26.000000            34.000000   10.000000      5.000000  2397.000000
# 75%    31.000000            36.000000   15.000000      8.000000  2818.000000
# max    36.000000            38.000000   36.000000     16.000000  3316.000000
#
#        Oynanan_Doksan_Dakika_Sayısı  Doksan_Dakika_Başına_Gol         xG
# count                     45.000000                 45.000000  45.000000
# mean                      25.081111                  0.506444  10.415556
# ...

# %%
veri.groupby("Oynadigi_Lig").aggregate({'Gol_Sayisi':['sum'],'Asist_Sayisi':['sum']})
# Out:
#              Gol_Sayisi Asist_Sayisi
#                     sum          sum
# Oynadigi_Lig
# Almanya              90           41
# Fransa              116           48
# İngiltere           127           63
# İspanya             109           50
# İtalya              111           45

# %%
veri.groupby("Mevki").aggregate({'Gol_Sayisi':['sum'],'Asist_Sayisi':['sum']})
# Out:
#           Gol_Sayisi Asist_Sayisi
#                  sum          sum
# Mevki
# Forvet           292           87
# Kanat            177          115
# Orta Saha         73           45
# Sol Bek            6            0
# Stoper             5            0

# %%
veri.groupby("Oynadigi_Takim").aggregate({'Gol_Sayisi':['sum'],'Asist_Sayisi':['sum']})
# Out:
#                 Gol_Sayisi Asist_Sayisi
#                        sum          sum
# Oynadigi_Takim
# Arsenal                 44           23
# Atletico Madrid         37           19
# B. Dortmund             23           13
# Barcelona               36           15
# Bayern Münih            36           17
# Lazio                   31           13
# Lens                    33           13
# Man.City                52           24
# Man.Utd                 31           16
# Marsilya                25            3
# Napoli                  44           17
# Paris SG                58           32
# RB Leipzig              31           11
# Real Madrid             36           16
# İnter                   36           15

# %%
veri.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18228\3754443863.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   veri.corr()
#                                    Yas  Oynadigi_Mac_Sayisi  Gol_Sayisi  \
# Yas                           1.000000            -0.037153   -0.013569
# Oynadigi_Mac_Sayisi          -0.037153             1.000000    0.212030
# Gol_Sayisi                   -0.013569             0.212030    1.000000
# Asist_Sayisi                  0.125864             0.281382    0.237457
# Aldığı_süre                   0.036429             0.755258    0.381359
# Oynanan_Doksan_Dakika_Sayısı  0.036405             0.755273    0.381379
# Doksan_Dakika_Başına_Gol     -0.013393            -0.363593    0.709942
# xG                            0.159504             0.221507    0.939477
#
# ...

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(veri.corr().abs(),  annot=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18228\583233437.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(veri.corr().abs(),  annot=True)
# <Axes: >

# %%
sns.pairplot(veri, kind="reg")

# %%
sns.jointplot(x="xG",y="Gol_Sayisi",data=veri, kind="reg")

# %%
import statsmodels.api as sm

# %%
X=veri[["xG"]]

# %%
y=veri[["Gol_Sayisi"]]

# %%
lm=sm.OLS(y,X)

# %%
model=lm.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             Gol_Sayisi   R-squared (uncentered):                   0.968
# Model:                            OLS   Adj. R-squared (uncentered):              0.967
# Method:                 Least Squares   F-statistic:                              1332.
# Date:                Sun, 11 Jun 2023   Prob (F-statistic):                    1.55e-34
# Time:                        13:06:20   Log-Likelihood:                         -105.21
# No. Observations:                  45   AIC:                                      212.4
# Df Residuals:                      44   BIC:                                      214.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X=sm.add_constant(X)

# %%
lm=sm.OLS(y,X)

# %%
model=lm.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Gol_Sayisi   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     323.3
# Date:                Sun, 11 Jun 2023   Prob (F-statistic):           1.27e-21
# Time:                        13:07:54   Log-Likelihood:                -101.57
# No. Observations:                  45   AIC:                             207.1
# Df Residuals:                      43   BIC:                             210.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8647      0.679      2.748      0.009       0.496       3.233
# ...

# %%
model.params
# Out:
# const    1.864689
# xG       1.000830
# dtype: float64

# %%
print("xG="+str("%.2f"%model.params[0])+"+Gol_Sayisi"+"*"+str("%.2f"%model.params[1]))
# Out:
# xG=1.86+Gol_Sayisi*1.00

# %%
from sklearn.linear_model import LinearRegression

# %%
X=veri[["xG"]]

# %%
y=veri[["Gol_Sayisi"]]

# %%
reg=LinearRegression()

# %%
model=reg.fit(X,y)

# %%
model.predict([[15]])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[16.87713826]])

# %%
veri[['xG','Gol_Sayisi']]
# Out:
#       xG  Gol_Sayisi
# 0    9.3          15
# 1   11.2          14
# 2   10.0          15
# 3   28.4          36
# 4    5.9          11
# 5    5.5           5
# 6   15.4          17
# 7    9.3           8
# 8    4.2           6
# 9   24.3          23
# 10   4.9           6
# 11   9.3           7
# 12  21.5          19
# 13  10.5          10
# 14   4.3           7
# 15  11.8          13
# 16  12.3          15
# 17   7.2           9
# 18  21.3          26
# 19   8.2          12
# 20   4.0           6
# 21  18.1          21
# 22   9.7           9
# 23   3.2           6
# 24  14.2          12
# 25   6.7          10
# 26   6.0           9
# 27   8.0          12
# 28   6.1          10
# 29  11.2          14
# 30   5.2           9
# 31   6.4           7
# 32   4.3           7
# 33  14.4          16
# 34   9.1           9
# 35   4.9           6
# 36  26.3          29
# 37  15.5          16
# 38   8.1          13
# 39  12.6          14
# 40   4.5           6
# 41   3.1           5
# ...
